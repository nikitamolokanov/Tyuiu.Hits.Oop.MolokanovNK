// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания 14

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Создать базовый класс Supplier в C#, который будет представлять информацию о
// поставщиках товаров или услуг. На основе этого класса разработать 2-3
// производных класса, демонстрирующих принципы наследования и полиморфизма.
// В каждом из классов должны быть реализованы новые атрибуты и методы, а также
// переопределены некоторые методы базового класса для демонстрации
// полиморфизма.

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;

public class Supplier
{
    public int SupplierId { get; set; }
    public string CompanyName { get; set; }
    public string ProductType { get; set; }

    public Supplier(int supplierId, string companyName, string productType)
    {
        SupplierId = supplierId;
        CompanyName = companyName;
        ProductType = productType;
    }

    public virtual void GetCompanyInfo()
    {
        Console.WriteLine($"ID: {SupplierId}, Компания: {CompanyName}, Продукция: {ProductType}");
    }

    public virtual void ProvideQuote()
    {
        Console.WriteLine($"Котировка от {CompanyName}: цена договорная, срок 30 дней");
    }

    public virtual void SubmitOrder()
    {
        Console.WriteLine($"Заказ отправлен {CompanyName}, статус: в обработке");
    }
}

public class Manufacturer : Supplier
{
    public int FoundedYear { get; set; }

    public Manufacturer(int supplierId, string companyName, string productType, int foundedYear)
        : base(supplierId, companyName, productType)
    {
        FoundedYear = foundedYear;
    }

    public override void ProvideQuote()
    {
        Console.WriteLine($"Котировка от производителя {CompanyName} (основан в {FoundedYear}): оптовая цена, срок 15 дней");
    }
}

public class Retailer : Supplier
{
    public string StoreLocation { get; set; }

    public Retailer(int supplierId, string companyName, string productType, string storeLocation)
        : base(supplierId, companyName, productType)
    {
        StoreLocation = storeLocation;
    }

    public override void SubmitOrder()
    {
        Console.WriteLine($"Заказ отправлен ритейлеру {CompanyName} (магазин: {StoreLocation}), самовывоз");
    }
}

public class Importer : Supplier
{
    public string OriginCountry { get; set; }

    public Importer(int supplierId, string companyName, string productType, string originCountry)
        : base(supplierId, companyName, productType)
    {
        OriginCountry = originCountry;
    }

    public override void GetCompanyInfo()
    {
        Console.WriteLine($"ID: {SupplierId}, Компания: {CompanyName}, Продукция: {ProductType}, Страна: {OriginCountry}");
    }
}

Manufacturer manufacturer = new Manufacturer(1, "ТехноПром", "Оборудование", 1995);
Retailer retailer = new Retailer(2, "ДомТехники", "Техника", "Москва");
Importer importer = new Importer(3, "ИмпортГрупп", "Электроника", "Китай");

Supplier[] suppliers = { manufacturer, retailer, importer };

foreach (var supplier in suppliers)
{
    supplier.GetCompanyInfo();
    supplier.ProvideQuote();
    supplier.SubmitOrder();
    Console.WriteLine();
}
// Out:
// ID: 1, Компания: ТехноПром, Продукция: Оборудование
// Котировка от производителя ТехноПром (основан в 1995): оптовая цена, срок 15 дней
// Заказ отправлен ТехноПром, статус: в обработке
//
// ID: 2, Компания: ДомТехники, Продукция: Техника
// Котировка от ДомТехники: цена договорная, срок 30 дней
// Заказ отправлен ритейлеру ДомТехники (магазин: Москва), самовывоз
//
// ID: 3, Компания: ИмпортГрупп, Продукция: Электроника, Страна: Китай
// Котировка от ИмпортГрупп: цена договорная, срок 30 дней
// Заказ отправлен ИмпортГрупп, статус: в обработке
